# %% [markdown]
# This is my first day text right here : Day 1

# %%
# %sql
SELECT * FROM orders
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.table('orders')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT * FROM csv.`/Volumes/workspace/default/youtubeseries/customerscsv.csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th></tr></thead><tbody><tr><td>customer_id</td><td>first_name</td><td>last_name</td><td>country</td><td>signup_date</td></tr><tr><td>101</td><td>Alice</td><td>Morgan</td><td>USA</td><td>2023-02-14</td></tr><tr><td>102</td><td>Ben</td><td>Singh</td><td>Canada</td><td>2023-03-22</td></tr><tr><td>103</td><td>Carla</td><td>Zhao</td><td>USA</td><td>2023-04-10</td></tr><tr><td>104</td><td>David</td><td>Lopez</td><td>UK</td><td>2023-05-02</td></tr><tr><td>105</td><td>Emma</td><td>Patel</td><td>USA</td><td>2023-06-18</td></tr></tbody></table></div>
